# %%
# Import dependencies 
import pandas as pd
import random
import numpy as np
import matplotlib.pyplot as plt
from citipy import citipy
import time
from datetime import datetime
import requests
import config

# %%
# create a set of random latitude and longitude combinations
lats=np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs=np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
#create list of coordinates from random lats/lngs
coordinates=list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# set up api key and url
weather_api_key = config.weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=metric&APPID="+weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=metric&APPID=bea398432acd279c0e2ba9e1a392cd33

# %%
#test api
city="Cape Town"
test = requests.get(url+"&q="+city.replace(" ","+")).json()

test['weather'][0]["description"]
# Out:
# 'clear sky'

# %%
# create empty list to hold weather data
city_data=[]

#indicate start of log
print("Starting Data Retreival")
print("-----------------------")

#create counters
record_count=1
set_count=1

#loop through all cities in list
for i, city in enumerate(cities):
    #group cities in 50 for logging
    if(i % 50 ==0 and i>=50):
        set_count += 1
        record_count +=1
        time.sleep(60)
        
    #create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    #log URL, record and set numbers and city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    #add 1 to the record count
    record_count+=1
    
    #run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_description,
                          "Country": city_country,
                          "Date": city_date})
        
        #if error is experienced skip city
    except:
        print("City not found. Skipping...")
        pass
#indicate end of data retrieval
print("-----------------------")
print("Complete")
print("-----------------------")
# Out:
# Starting Data Retreival
# -----------------------
# Processing Record 1 of Set 1 | atuona
# Processing Record 2 of Set 1 | savonlinna
# Processing Record 3 of Set 1 | linchuan
# City not found. Skipping...
# Processing Record 4 of Set 1 | flinders
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 1 | chuy
# Processing Record 8 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 1 | turukhansk
# Processing Record 10 of Set 1 | nikolskoye
# Processing Record 11 of Set 1 | kapaa
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | usta muhammad
# Processing Record 14 of Set 1 | maumere
# Processing Record 15 of Set 1 | hobart
# Processing Record 16 of Set 1 | cordele
# Processing Record 17 of Set 1 | avarua
# Processing Record 18 of Set 1 | hofn
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | lata
# Processing Record 21 of Set 1 | namatanai
# Processing Record 22 of Set 1 | buin
# Processing Record 23 of Set 1 | havelock
# Processing Record 24 of Set 1 | oyama
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | berdigestyakh
# Processing Record 27 of Set 1 | busselton
# Processing Record 28 of Set 1 | poum
# Processing Record 29 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 1 | yerbogachen
# Processing Record 31 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 1 | vaini
# Processing Record 33 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 1 | tuktoyaktuk
# Processing Record 35 of Set 1 | teya
# Processing Record 36 of Set 1 | tres arroyos
# Processing Record 37 of Set 1 | hithadhoo
# Processing Record 38 of Set 1 | tasiilaq
# Processing Record 39 of Set 1 | gat
# Processing Record 40 of Set 1 | san patricio
# Processing Record 41 of Set 1 | sao filipe
# Processing Record 42 of Set 1 | jamestown
# Processing Record 43 of Set 1 | dikson
# Processing Record 44 of Set 1 | butaritari
# Processing Record 45 of Set 1 | puqi
# Processing Record 46 of Set 1 | hilo
# Processing Record 47 of Set 1 | cape town
# Processing Record 48 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 1 | viligili
# City not found. Skipping...
# Processing Record 50 of Set 1 | castro
# Processing Record 52 of Set 2 | thompson
# Processing Record 53 of Set 2 | mount gambier
# Processing Record 54 of Set 2 | ketchikan
# Processing Record 55 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 56 of Set 2 | puerto escondido
# Processing Record 57 of Set 2 | torbay
# Processing Record 58 of Set 2 | itoman
# Processing Record 59 of Set 2 | upernavik
# Processing Record 60 of Set 2 | wattegama
# Processing Record 61 of Set 2 | shirhatti
# Processing Record 62 of Set 2 | yarada
# Processing Record 63 of Set 2 | sao jose da coroa grande
# Processing Record 64 of Set 2 | kenai
# Processing Record 65 of Set 2 | cayenne
# Processing Record 66 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 67 of Set 2 | ilulissat
# Processing Record 68 of Set 2 | cap malheureux
# Processing Record 69 of Set 2 | mackay
# Processing Record 70 of Set 2 | esperance
# Processing Record 71 of Set 2 | preobrazheniye
# Processing Record 72 of Set 2 | east london
# Processing Record 73 of Set 2 | bredasdorp
# Processing Record 74 of Set 2 | yanam
# Processing Record 75 of Set 2 | souillac
# Processing Record 76 of Set 2 | chokurdakh
# Processing Record 77 of Set 2 | georgetown
# Processing Record 78 of Set 2 | mataura
# Processing Record 79 of Set 2 | lorengau
# Processing Record 80 of Set 2 | semirom
# Processing Record 81 of Set 2 | trinidad
# Processing Record 82 of Set 2 | yenagoa
# Processing Record 83 of Set 2 | hermanus
# Processing Record 84 of Set 2 | bengkulu
# Processing Record 85 of Set 2 | norman wells
# Processing Record 86 of Set 2 | yellowknife
# Processing Record 87 of Set 2 | saint-philippe
# Processing Record 88 of Set 2 | jeremie
# Processing Record 89 of Set 2 | new norfolk
# Processing Record 90 of Set 2 | puerto ayora
# Processing Record 91 of Set 2 | nanortalik
# Processing Record 92 of Set 2 | kodiak
# Processing Record 93 of Set 2 | honiara
# Processing Record 94 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 95 of Set 2 | guozhen
# Processing Record 96 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 97 of Set 2 | ihosy
# Processing Record 98 of Set 2 | gubkinskiy
# Processing Record 99 of Set 2 | saint george
# Processing Record 100 of Set 2 | alofi
# Processing Record 101 of Set 2 | taoudenni
# Processing Record 103 of Set 3 | bluff
# Processing Record 104 of Set 3 | uruguaiana
# Processing Record 105 of Set 3 | the valley
# Processing Record 106 of Set 3 | mahebourg
# Processing Record 107 of Set 3 | shenjiamen
# Processing Record 108 of Set 3 | quatre cocos
# Processing Record 109 of Set 3 | kabin buri
# Processing Record 110 of Set 3 | san andres
# Processing Record 111 of Set 3 | vaitape
# Processing Record 112 of Set 3 | luderitz
# Processing Record 113 of Set 3 | fort collins
# Processing Record 114 of Set 3 | pevek
# Processing Record 115 of Set 3 | a
# City not found. Skipping...
# Processing Record 116 of Set 3 | piacabucu
# Processing Record 117 of Set 3 | kurilsk
# Processing Record 118 of Set 3 | grindavik
# Processing Record 119 of Set 3 | stettler
# Processing Record 120 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 121 of Set 3 | lebu
# Processing Record 122 of Set 3 | taganak
# Processing Record 123 of Set 3 | vanimo
# Processing Record 124 of Set 3 | khatanga
# Processing Record 125 of Set 3 | fortuna
# Processing Record 126 of Set 3 | beaverlodge
# Processing Record 127 of Set 3 | chulman
# Processing Record 128 of Set 3 | dwarka
# Processing Record 129 of Set 3 | havre-saint-pierre
# Processing Record 130 of Set 3 | the pas
# Processing Record 131 of Set 3 | longyearbyen
# Processing Record 132 of Set 3 | kaka
# Processing Record 133 of Set 3 | ponta do sol
# Processing Record 134 of Set 3 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 135 of Set 3 | pisco
# Processing Record 136 of Set 3 | rocha
# Processing Record 137 of Set 3 | muros
# Processing Record 138 of Set 3 | shingu
# Processing Record 139 of Set 3 | carnarvon
# Processing Record 140 of Set 3 | jalu
# Processing Record 141 of Set 3 | matadi
# Processing Record 142 of Set 3 | porto velho
# Processing Record 143 of Set 3 | gualaquiza
# Processing Record 144 of Set 3 | sarkand
# Processing Record 145 of Set 3 | carlisle
# Processing Record 146 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 147 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 148 of Set 3 | tautira
# Processing Record 149 of Set 3 | narsaq
# Processing Record 150 of Set 3 | mareeba
# Processing Record 151 of Set 3 | candelaria
# Processing Record 152 of Set 3 | ishikawa
# Processing Record 154 of Set 4 | ancud
# Processing Record 155 of Set 4 | leningradskiy
# Processing Record 156 of Set 4 | taksimo
# Processing Record 157 of Set 4 | lowestoft
# Processing Record 158 of Set 4 | kaili
# Processing Record 159 of Set 4 | sheregesh
# Processing Record 160 of Set 4 | barrow
# Processing Record 161 of Set 4 | karratha
# Processing Record 162 of Set 4 | victoria
# Processing Record 163 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 164 of Set 4 | pangnirtung
# Processing Record 165 of Set 4 | kaitangata
# Processing Record 166 of Set 4 | sao joao da barra
# Processing Record 167 of Set 4 | campbell river
# Processing Record 168 of Set 4 | tual
# Processing Record 169 of Set 4 | sao sepe
# Processing Record 170 of Set 4 | makakilo city
# Processing Record 171 of Set 4 | edmonton
# Processing Record 172 of Set 4 | rostov-na-donu
# Processing Record 173 of Set 4 | husavik
# Processing Record 174 of Set 4 | portland
# Processing Record 175 of Set 4 | raudeberg
# Processing Record 176 of Set 4 | fukue
# Processing Record 177 of Set 4 | kirakira
# Processing Record 178 of Set 4 | port elizabeth
# Processing Record 179 of Set 4 | verkhnyaya inta
# Processing Record 180 of Set 4 | provideniya
# Processing Record 181 of Set 4 | edd
# Processing Record 182 of Set 4 | qaanaaq
# Processing Record 183 of Set 4 | impfondo
# Processing Record 184 of Set 4 | glendive
# Processing Record 185 of Set 4 | padang
# Processing Record 186 of Set 4 | kabanjahe
# Processing Record 187 of Set 4 | guanare
# Processing Record 188 of Set 4 | sur
# Processing Record 189 of Set 4 | port alfred
# Processing Record 190 of Set 4 | kruisfontein
# Processing Record 191 of Set 4 | naryan-mar
# Processing Record 192 of Set 4 | calvinia
# Processing Record 193 of Set 4 | oktyabrskiy
# Processing Record 194 of Set 4 | burdur
# Processing Record 195 of Set 4 | malwan
# City not found. Skipping...
# Processing Record 196 of Set 4 | port-gentil
# Processing Record 197 of Set 4 | mount pleasant
# Processing Record 198 of Set 4 | alamosa
# Processing Record 199 of Set 4 | saldanha
# Processing Record 200 of Set 4 | denau
# City not found. Skipping...
# Processing Record 201 of Set 4 | lompoc
# Processing Record 202 of Set 4 | saskylakh
# Processing Record 203 of Set 4 | talnakh
# Processing Record 205 of Set 5 | achisay
# City not found. Skipping...
# Processing Record 206 of Set 5 | vila franca do campo
# Processing Record 207 of Set 5 | bethel
# Processing Record 208 of Set 5 | tchollire
# Processing Record 209 of Set 5 | pacific grove
# Processing Record 210 of Set 5 | locri
# Processing Record 211 of Set 5 | riberalta
# Processing Record 212 of Set 5 | namibe
# Processing Record 213 of Set 5 | katobu
# Processing Record 214 of Set 5 | sidi bu zayd
# City not found. Skipping...
# Processing Record 215 of Set 5 | aklavik
# Processing Record 216 of Set 5 | mar del plata
# Processing Record 217 of Set 5 | dapitan
# Processing Record 218 of Set 5 | ola
# Processing Record 219 of Set 5 | takoradi
# Processing Record 220 of Set 5 | bagado
# Processing Record 221 of Set 5 | nizhniy tsasuchey
# Processing Record 222 of Set 5 | vila velha
# Processing Record 223 of Set 5 | tiksi
# Processing Record 224 of Set 5 | tura
# Processing Record 225 of Set 5 | paamiut
# Processing Record 226 of Set 5 | kavaratti
# Processing Record 227 of Set 5 | kijang
# Processing Record 228 of Set 5 | tamandare
# Processing Record 229 of Set 5 | haibowan
# City not found. Skipping...
# Processing Record 230 of Set 5 | innisfail
# Processing Record 231 of Set 5 | alakurtti
# Processing Record 232 of Set 5 | kaeo
# Processing Record 233 of Set 5 | finote selam
# Processing Record 234 of Set 5 | san buenaventura
# Processing Record 235 of Set 5 | hami
# Processing Record 236 of Set 5 | evensk
# Processing Record 237 of Set 5 | iskateley
# Processing Record 238 of Set 5 | khani
# Processing Record 239 of Set 5 | arraial do cabo
# Processing Record 240 of Set 5 | airai
# Processing Record 241 of Set 5 | palu
# Processing Record 242 of Set 5 | praia da vitoria
# Processing Record 243 of Set 5 | dunedin
# Processing Record 244 of Set 5 | bambous virieux
# Processing Record 245 of Set 5 | tondon
# Processing Record 246 of Set 5 | san quintin
# Processing Record 247 of Set 5 | eldorado
# Processing Record 248 of Set 5 | ribeira grande
# Processing Record 249 of Set 5 | pirgos
# Processing Record 250 of Set 5 | berlevag
# Processing Record 251 of Set 5 | ixtapa
# Processing Record 252 of Set 5 | cidreira
# Processing Record 253 of Set 5 | kizlyar
# Processing Record 254 of Set 5 | gweta
# Processing Record 256 of Set 6 | beringovskiy
# Processing Record 257 of Set 6 | paidha
# Processing Record 258 of Set 6 | moindou
# Processing Record 259 of Set 6 | klaksvik
# Processing Record 260 of Set 6 | jiazi
# Processing Record 261 of Set 6 | iqaluit
# Processing Record 262 of Set 6 | mikhaylovka
# Processing Record 263 of Set 6 | caravelas
# Processing Record 264 of Set 6 | coihaique
# Processing Record 265 of Set 6 | chapais
# Processing Record 266 of Set 6 | kavieng
# Processing Record 267 of Set 6 | borovnica
# Processing Record 268 of Set 6 | geraldton
# Processing Record 269 of Set 6 | den helder
# Processing Record 270 of Set 6 | ulladulla
# Processing Record 271 of Set 6 | duz
# City not found. Skipping...
# Processing Record 272 of Set 6 | navrongo
# Processing Record 273 of Set 6 | lokoja
# Processing Record 274 of Set 6 | margate
# Processing Record 275 of Set 6 | clyde river
# Processing Record 276 of Set 6 | pozo colorado
# Processing Record 277 of Set 6 | tessalit
# Processing Record 278 of Set 6 | lazaro cardenas
# Processing Record 279 of Set 6 | roma
# Processing Record 280 of Set 6 | port-cartier
# Processing Record 281 of Set 6 | hamilton
# Processing Record 282 of Set 6 | kahului
# Processing Record 283 of Set 6 | beba
# Processing Record 284 of Set 6 | remedios
# Processing Record 285 of Set 6 | chunoyar
# Processing Record 286 of Set 6 | palos heights
# Processing Record 287 of Set 6 | holme
# Processing Record 288 of Set 6 | severo-kurilsk
# Processing Record 289 of Set 6 | westport
# Processing Record 290 of Set 6 | cururupu
# Processing Record 291 of Set 6 | kawana waters
# City not found. Skipping...
# Processing Record 292 of Set 6 | freeport
# Processing Record 293 of Set 6 | polovinnoye
# Processing Record 294 of Set 6 | pilar
# Processing Record 295 of Set 6 | konispol
# Processing Record 296 of Set 6 | vardo
# Processing Record 297 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 298 of Set 6 | anjozorobe
# Processing Record 299 of Set 6 | shieli
# Processing Record 300 of Set 6 | maneromango
# Processing Record 301 of Set 6 | cabo san lucas
# Processing Record 302 of Set 6 | faanui
# Processing Record 303 of Set 6 | san policarpo
# Processing Record 304 of Set 6 | yulara
# Processing Record 305 of Set 6 | senneterre
# Processing Record 307 of Set 7 | tuatapere
# Processing Record 308 of Set 7 | kachikau
# City not found. Skipping...
# Processing Record 309 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 310 of Set 7 | sovetskiy
# Processing Record 311 of Set 7 | ludvika
# Processing Record 312 of Set 7 | suicheng
# Processing Record 313 of Set 7 | oistins
# Processing Record 314 of Set 7 | inirida
# Processing Record 315 of Set 7 | hudson bay
# Processing Record 316 of Set 7 | safaqis
# City not found. Skipping...
# Processing Record 317 of Set 7 | isangel
# Processing Record 318 of Set 7 | matagami
# Processing Record 319 of Set 7 | lagos
# Processing Record 320 of Set 7 | atar
# Processing Record 321 of Set 7 | grootfontein
# Processing Record 322 of Set 7 | fukuma
# Processing Record 323 of Set 7 | baiyin
# Processing Record 324 of Set 7 | concepcion
# Processing Record 325 of Set 7 | bilma
# Processing Record 326 of Set 7 | nome
# Processing Record 327 of Set 7 | pokrovsk
# Processing Record 328 of Set 7 | andijon
# Processing Record 329 of Set 7 | abu samrah
# Processing Record 330 of Set 7 | kampong chhnang
# Processing Record 331 of Set 7 | nagybajom
# Processing Record 332 of Set 7 | balimo
# City not found. Skipping...
# Processing Record 333 of Set 7 | bicester
# Processing Record 334 of Set 7 | wangdiphodrang
# City not found. Skipping...
# Processing Record 335 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 336 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 337 of Set 7 | gao
# Processing Record 338 of Set 7 | churapcha
# Processing Record 339 of Set 7 | inuvik
# Processing Record 340 of Set 7 | barentu
# Processing Record 341 of Set 7 | adrar
# Processing Record 342 of Set 7 | bullhead city
# Processing Record 343 of Set 7 | waingapu
# Processing Record 344 of Set 7 | kropotkin
# Processing Record 345 of Set 7 | saint-augustin
# Processing Record 346 of Set 7 | thunder bay
# Processing Record 347 of Set 7 | draganesti-vlasca
# Processing Record 348 of Set 7 | alenquer
# Processing Record 349 of Set 7 | harper
# Processing Record 350 of Set 7 | moron
# Processing Record 351 of Set 7 | zhezkazgan
# Processing Record 352 of Set 7 | vestmannaeyjar
# Processing Record 353 of Set 7 | kalianget
# Processing Record 354 of Set 7 | eureka
# Processing Record 355 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 356 of Set 7 | guiratinga
# Processing Record 358 of Set 8 | qaqortoq
# Processing Record 359 of Set 8 | imperial
# Processing Record 360 of Set 8 | shorapur
# Processing Record 361 of Set 8 | asau
# Processing Record 362 of Set 8 | lagoa
# Processing Record 363 of Set 8 | mayo
# Processing Record 364 of Set 8 | talawakele
# Processing Record 365 of Set 8 | moorhead
# Processing Record 366 of Set 8 | kutum
# Processing Record 367 of Set 8 | moose factory
# Processing Record 368 of Set 8 | sakakah
# Processing Record 369 of Set 8 | tambura
# Processing Record 370 of Set 8 | zhigansk
# Processing Record 371 of Set 8 | burgeo
# Processing Record 372 of Set 8 | black river
# Processing Record 373 of Set 8 | maldonado
# Processing Record 374 of Set 8 | beian
# Processing Record 375 of Set 8 | port blair
# Processing Record 376 of Set 8 | polyarnyy
# Processing Record 377 of Set 8 | lardos
# Processing Record 378 of Set 8 | coquimbo
# Processing Record 379 of Set 8 | xapuri
# Processing Record 380 of Set 8 | huilong
# Processing Record 381 of Set 8 | bembereke
# Processing Record 382 of Set 8 | tiznit
# Processing Record 383 of Set 8 | eaglesfield
# Processing Record 384 of Set 8 | srednekolymsk
# Processing Record 385 of Set 8 | bossangoa
# Processing Record 386 of Set 8 | san cristobal
# Processing Record 387 of Set 8 | jumla
# Processing Record 388 of Set 8 | verkhoyansk
# Processing Record 389 of Set 8 | nacala
# Processing Record 390 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 391 of Set 8 | caibarien
# Processing Record 392 of Set 8 | alexandria
# Processing Record 393 of Set 8 | kalmunai
# Processing Record 394 of Set 8 | sierra vista
# Processing Record 395 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 396 of Set 8 | codrington
# Processing Record 397 of Set 8 | senanga
# Processing Record 398 of Set 8 | los llanos de aridane
# Processing Record 399 of Set 8 | ust-karsk
# Processing Record 400 of Set 8 | caconda
# Processing Record 401 of Set 8 | chiari
# Processing Record 402 of Set 8 | miquelon
# Processing Record 403 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 404 of Set 8 | emmett
# Processing Record 405 of Set 8 | peruibe
# Processing Record 406 of Set 8 | marshall
# Processing Record 407 of Set 8 | almonte
# Processing Record 409 of Set 9 | sisimiut
# Processing Record 410 of Set 9 | saint-georges
# Processing Record 411 of Set 9 | southern pines
# Processing Record 412 of Set 9 | vanavara
# Processing Record 413 of Set 9 | wajir
# Processing Record 414 of Set 9 | yar-sale
# Processing Record 415 of Set 9 | maposeni
# Processing Record 416 of Set 9 | walvis bay
# Processing Record 417 of Set 9 | mantua
# Processing Record 418 of Set 9 | totness
# Processing Record 419 of Set 9 | sola
# Processing Record 420 of Set 9 | saint anthony
# Processing Record 421 of Set 9 | okhotsk
# Processing Record 422 of Set 9 | samarai
# Processing Record 423 of Set 9 | panama city
# Processing Record 424 of Set 9 | belen
# Processing Record 425 of Set 9 | fuyang
# Processing Record 426 of Set 9 | sungaipenuh
# Processing Record 427 of Set 9 | xinzhi
# Processing Record 428 of Set 9 | calbuco
# Processing Record 429 of Set 9 | santa maria del oro
# Processing Record 430 of Set 9 | orange cove
# Processing Record 431 of Set 9 | asnaes
# Processing Record 432 of Set 9 | manzhouli
# Processing Record 433 of Set 9 | te anau
# Processing Record 434 of Set 9 | lethem
# Processing Record 435 of Set 9 | ratnagiri
# Processing Record 436 of Set 9 | hervey bay
# Processing Record 437 of Set 9 | sorong
# Processing Record 438 of Set 9 | puerto leguizamo
# Processing Record 439 of Set 9 | kusk
# City not found. Skipping...
# Processing Record 440 of Set 9 | iwanai
# Processing Record 441 of Set 9 | beira
# Processing Record 442 of Set 9 | dubno
# Processing Record 443 of Set 9 | byron bay
# Processing Record 444 of Set 9 | cherskiy
# Processing Record 445 of Set 9 | goderich
# Processing Record 446 of Set 9 | aykino
# Processing Record 447 of Set 9 | alekseyevka
# Processing Record 448 of Set 9 | townsville
# Processing Record 449 of Set 9 | bezhta
# Processing Record 450 of Set 9 | sitka
# Processing Record 451 of Set 9 | huarmey
# Processing Record 452 of Set 9 | ovsyanka
# Processing Record 453 of Set 9 | corsicana
# Processing Record 454 of Set 9 | moree
# Processing Record 455 of Set 9 | sri aman
# Processing Record 456 of Set 9 | maltahohe
# Processing Record 457 of Set 9 | severobaykalsk
# Processing Record 458 of Set 9 | luan
# Processing Record 460 of Set 10 | montrose
# Processing Record 461 of Set 10 | mazagao
# Processing Record 462 of Set 10 | baracoa
# Processing Record 463 of Set 10 | calnali
# Processing Record 464 of Set 10 | homer
# Processing Record 465 of Set 10 | kaoma
# Processing Record 466 of Set 10 | el tigre
# Processing Record 467 of Set 10 | sun valley
# Processing Record 468 of Set 10 | waipawa
# Processing Record 469 of Set 10 | bozoum
# Processing Record 470 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 471 of Set 10 | sinop
# Processing Record 472 of Set 10 | santa cruz
# Processing Record 473 of Set 10 | macae
# Processing Record 474 of Set 10 | kyren
# Processing Record 475 of Set 10 | chaa-khol
# City not found. Skipping...
# Processing Record 476 of Set 10 | burnie
# Processing Record 477 of Set 10 | wukari
# Processing Record 478 of Set 10 | batagay
# Processing Record 479 of Set 10 | itapora
# Processing Record 480 of Set 10 | bombay
# Processing Record 481 of Set 10 | khash
# Processing Record 482 of Set 10 | lasa
# Processing Record 483 of Set 10 | aleksandrow kujawski
# Processing Record 484 of Set 10 | bria
# Processing Record 485 of Set 10 | ubinskoye
# Processing Record 486 of Set 10 | seguela
# Processing Record 487 of Set 10 | jablah
# Processing Record 488 of Set 10 | hualmay
# Processing Record 489 of Set 10 | saint-pierre
# Processing Record 490 of Set 10 | havoysund
# Processing Record 491 of Set 10 | emba
# Processing Record 492 of Set 10 | tromso
# Processing Record 493 of Set 10 | richards bay
# Processing Record 494 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 495 of Set 10 | aguimes
# Processing Record 496 of Set 10 | laguna
# Processing Record 497 of Set 10 | malartic
# Processing Record 498 of Set 10 | namyslow
# Processing Record 499 of Set 10 | vagur
# Processing Record 500 of Set 10 | marivan
# Processing Record 501 of Set 10 | ostrovnoy
# Processing Record 502 of Set 10 | antofagasta
# Processing Record 503 of Set 10 | port victoria
# Processing Record 504 of Set 10 | ahipara
# Processing Record 505 of Set 10 | omboue
# Processing Record 506 of Set 10 | teguise
# Processing Record 507 of Set 10 | yinchuan
# Processing Record 508 of Set 10 | kuusamo
# Processing Record 509 of Set 10 | along
# Processing Record 511 of Set 11 | tambun
# Processing Record 512 of Set 11 | ambon
# Processing Record 513 of Set 11 | bronnoysund
# Processing Record 514 of Set 11 | banda aceh
# Processing Record 515 of Set 11 | nouadhibou
# Processing Record 516 of Set 11 | avera
# Processing Record 517 of Set 11 | el seibo
# Processing Record 518 of Set 11 | ngunguru
# Processing Record 519 of Set 11 | derzhavinsk
# Processing Record 520 of Set 11 | alihe
# Processing Record 521 of Set 11 | najran
# Processing Record 522 of Set 11 | ojinaga
# Processing Record 523 of Set 11 | caldwell
# Processing Record 524 of Set 11 | istok
# Processing Record 525 of Set 11 | hurricane
# Processing Record 526 of Set 11 | kungurtug
# Processing Record 527 of Set 11 | ca mau
# Processing Record 528 of Set 11 | port lincoln
# Processing Record 529 of Set 11 | marsh harbour
# Processing Record 530 of Set 11 | port hueneme
# Processing Record 531 of Set 11 | ternate
# Processing Record 532 of Set 11 | dingle
# Processing Record 533 of Set 11 | komsomolskiy
# Processing Record 534 of Set 11 | luanda
# Processing Record 535 of Set 11 | corciano
# Processing Record 536 of Set 11 | bandrele
# Processing Record 537 of Set 11 | aripuana
# Processing Record 538 of Set 11 | capoterra
# Processing Record 539 of Set 11 | wanning
# Processing Record 540 of Set 11 | paracatu
# Processing Record 541 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 542 of Set 11 | faya
# Processing Record 543 of Set 11 | ponta delgada
# Processing Record 544 of Set 11 | koudougou
# Processing Record 545 of Set 11 | kanniyakumari
# Processing Record 546 of Set 11 | bubaque
# Processing Record 547 of Set 11 | nadym
# Processing Record 548 of Set 11 | rayong
# Processing Record 549 of Set 11 | hobyo
# Processing Record 550 of Set 11 | bowen
# Processing Record 551 of Set 11 | dapdap
# Processing Record 552 of Set 11 | trairi
# Processing Record 553 of Set 11 | turbat
# Processing Record 554 of Set 11 | camacha
# Processing Record 555 of Set 11 | pula
# Processing Record 556 of Set 11 | ilebo
# Processing Record 557 of Set 11 | sayyan
# Processing Record 558 of Set 11 | bagan
# Processing Record 559 of Set 11 | humboldt
# Processing Record 560 of Set 11 | valleyview
# Processing Record 562 of Set 12 | touros
# Processing Record 563 of Set 12 | pavino
# Processing Record 564 of Set 12 | moramanga
# Processing Record 565 of Set 12 | manggar
# Processing Record 566 of Set 12 | leninskoye
# Processing Record 567 of Set 12 | vieques
# Processing Record 568 of Set 12 | dhangadhi
# Processing Record 569 of Set 12 | dalbandin
# Processing Record 570 of Set 12 | naze
# Processing Record 571 of Set 12 | sobolevo
# Processing Record 572 of Set 12 | bam
# Processing Record 573 of Set 12 | kodinsk
# Processing Record 574 of Set 12 | lavrentiya
# Processing Record 575 of Set 12 | ucluelet
# Processing Record 576 of Set 12 | coahuayana
# Processing Record 577 of Set 12 | makokou
# Processing Record 578 of Set 12 | bonthe
# Processing Record 579 of Set 12 | zhangye
# Processing Record 580 of Set 12 | zyryanka
# Processing Record 581 of Set 12 | kapuskasing
# Processing Record 582 of Set 12 | egvekinot
# Processing Record 583 of Set 12 | isla vista
# Processing Record 584 of Set 12 | certegui
# Processing Record 585 of Set 12 | urumqi
# Processing Record 586 of Set 12 | wulanhaote
# City not found. Skipping...
# Processing Record 587 of Set 12 | kasongo-lunda
# Processing Record 588 of Set 12 | comodoro rivadavia
# Processing Record 589 of Set 12 | elizabeth city
# Processing Record 590 of Set 12 | kathmandu
# Processing Record 591 of Set 12 | lubango
# Processing Record 592 of Set 12 | leshukonskoye
# Processing Record 593 of Set 12 | rostaq
# City not found. Skipping...
# Processing Record 594 of Set 12 | viedma
# Processing Record 595 of Set 12 | kampene
# Processing Record 596 of Set 12 | farafangana
# Processing Record 597 of Set 12 | sulangan
# Processing Record 598 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 599 of Set 12 | maniitsoq
# Processing Record 600 of Set 12 | pathein
# Processing Record 601 of Set 12 | yumbo
# Processing Record 602 of Set 12 | ugoofaaru
# Processing Record 603 of Set 12 | puerto del rosario
# Processing Record 604 of Set 12 | bandarbeyla
# Processing Record 605 of Set 12 | lodja
# Processing Record 606 of Set 12 | phan thiet
# Processing Record 607 of Set 12 | bahia blanca
# Processing Record 608 of Set 12 | yablonovo
# Processing Record 609 of Set 12 | popondetta
# Processing Record 610 of Set 12 | yining
# Processing Record 611 of Set 12 | beloha
# Processing Record 613 of Set 13 | wembley
# Processing Record 614 of Set 13 | pacifica
# Processing Record 615 of Set 13 | uglovskoye
# Processing Record 616 of Set 13 | iberia
# Processing Record 617 of Set 13 | korla
# Processing Record 618 of Set 13 | general roca
# Processing Record 619 of Set 13 | gombe
# Processing Record 620 of Set 13 | gisborne
# Processing Record 621 of Set 13 | chicama
# Processing Record 622 of Set 13 | ortisoara
# Processing Record 623 of Set 13 | ardistan
# City not found. Skipping...
# Processing Record 624 of Set 13 | alanya
# Processing Record 625 of Set 13 | quepos
# Processing Record 626 of Set 13 | camana
# Processing Record 627 of Set 13 | iracoubo
# Processing Record 628 of Set 13 | bainbridge
# Processing Record 629 of Set 13 | sandpoint
# Processing Record 630 of Set 13 | hasaki
# Processing Record 631 of Set 13 | tateyama
# Processing Record 632 of Set 13 | lakes entrance
# Processing Record 633 of Set 13 | elko
# Processing Record 634 of Set 13 | ovalle
# Processing Record 635 of Set 13 | kriel
# Processing Record 636 of Set 13 | broken hill
# Processing Record 637 of Set 13 | clarksburg
# Processing Record 638 of Set 13 | ishigaki
# Processing Record 639 of Set 13 | vostok
# Processing Record 640 of Set 13 | santa maria
# Processing Record 641 of Set 13 | dicamay
# Processing Record 642 of Set 13 | cuamba
# Processing Record 643 of Set 13 | constitucion
# Processing Record 644 of Set 13 | proletarsk
# Processing Record 645 of Set 13 | kunashak
# Processing Record 646 of Set 13 | miracema do tocantins
# Processing Record 647 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 648 of Set 13 | alice springs
# Processing Record 649 of Set 13 | djambala
# Processing Record 650 of Set 13 | jacareacanga
# Processing Record 651 of Set 13 | ust-nera
# Processing Record 652 of Set 13 | vao
# Processing Record 653 of Set 13 | lloydminster
# Processing Record 654 of Set 13 | salalah
# Processing Record 655 of Set 13 | kudahuvadhoo
# Processing Record 656 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 657 of Set 13 | xicotencatl
# Processing Record 658 of Set 13 | seminole
# Processing Record 659 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 660 of Set 13 | canon city
# Processing Record 661 of Set 13 | dudinka
# Processing Record 662 of Set 13 | san jeronimo
# Processing Record 664 of Set 14 | bud
# Processing Record 665 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 666 of Set 14 | dubenskiy
# City not found. Skipping...
# Processing Record 667 of Set 14 | cheuskiny
# City not found. Skipping...
# Processing Record 668 of Set 14 | baykit
# Processing Record 669 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 670 of Set 14 | parit buntar
# Processing Record 671 of Set 14 | poya
# Processing Record 672 of Set 14 | abha
# Processing Record 673 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 674 of Set 14 | karlskoga
# Processing Record 675 of Set 14 | kuruman
# Processing Record 676 of Set 14 | tamale
# Processing Record 677 of Set 14 | saint-joseph
# Processing Record 678 of Set 14 | albury
# Processing Record 679 of Set 14 | tucurui
# Processing Record 680 of Set 14 | kosh-agach
# Processing Record 681 of Set 14 | grand-santi
# Processing Record 682 of Set 14 | katsuura
# Processing Record 683 of Set 14 | les cayes
# Processing Record 684 of Set 14 | tazovskiy
# Processing Record 685 of Set 14 | rwamagana
# Processing Record 686 of Set 14 | le port
# Processing Record 687 of Set 14 | el prat de llobregat
# Processing Record 688 of Set 14 | bathsheba
# Processing Record 689 of Set 14 | biltine
# Processing Record 690 of Set 14 | loveland
# Processing Record 691 of Set 14 | lambare
# Processing Record 692 of Set 14 | aksu
# Processing Record 693 of Set 14 | seymchan
# Processing Record 694 of Set 14 | bushehr
# Processing Record 695 of Set 14 | riyadh
# Processing Record 696 of Set 14 | mwinilunga
# Processing Record 697 of Set 14 | port shepstone
# Processing Record 698 of Set 14 | lexington
# Processing Record 699 of Set 14 | great yarmouth
# Processing Record 700 of Set 14 | russell
# Processing Record 701 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 702 of Set 14 | abalak
# Processing Record 703 of Set 14 | juneau
# Processing Record 704 of Set 14 | sayat
# Processing Record 705 of Set 14 | price
# Processing Record 706 of Set 14 | riachao
# Processing Record 707 of Set 14 | springfield
# Processing Record 708 of Set 14 | sherbakul
# Processing Record 709 of Set 14 | panaba
# Processing Record 710 of Set 14 | porto torres
# Processing Record 711 of Set 14 | miri
# Processing Record 712 of Set 14 | daru
# Processing Record 713 of Set 14 | port moresby
# Processing Record 715 of Set 15 | luwuk
# Processing Record 716 of Set 15 | novikovo
# Processing Record 717 of Set 15 | talakan
# Processing Record 718 of Set 15 | trelew
# Processing Record 719 of Set 15 | diapaga
# Processing Record 720 of Set 15 | muravlenko
# Processing Record 721 of Set 15 | bijar
# Processing Record 722 of Set 15 | inta
# Processing Record 723 of Set 15 | pilar do sul
# Processing Record 724 of Set 15 | zatoka
# Processing Record 725 of Set 15 | san carlos de bariloche
# Processing Record 726 of Set 15 | nuristan
# Processing Record 727 of Set 15 | lima
# Processing Record 728 of Set 15 | zeya
# Processing Record 729 of Set 15 | lodwar
# Processing Record 730 of Set 15 | atherton
# Processing Record 731 of Set 15 | beterou
# Processing Record 732 of Set 15 | stokmarknes
# Processing Record 733 of Set 15 | merauke
# Processing Record 734 of Set 15 | nikolayevsk-na-amure
# Processing Record 735 of Set 15 | kuching
# Processing Record 736 of Set 15 | lock haven
# Processing Record 737 of Set 15 | chilliwack
# Processing Record 738 of Set 15 | gavle
# Processing Record 739 of Set 15 | weligama
# Processing Record 740 of Set 15 | rio sereno
# Processing Record 741 of Set 15 | california city
# Processing Record 742 of Set 15 | bafata
# Processing Record 743 of Set 15 | luganville
# Processing Record 744 of Set 15 | mehamn
# Processing Record 745 of Set 15 | tilichiki
# Processing Record 746 of Set 15 | nhulunbuy
# Processing Record 747 of Set 15 | miraflores
# Processing Record 748 of Set 15 | methoni
# Processing Record 749 of Set 15 | suntar
# Processing Record 750 of Set 15 | dori
# Processing Record 751 of Set 15 | hunza
# City not found. Skipping...
# Processing Record 752 of Set 15 | villa carlos paz
# Processing Record 753 of Set 15 | bull savanna
# Processing Record 754 of Set 15 | awbari
# Processing Record 755 of Set 15 | okandja
# City not found. Skipping...
# -----------------------
# Complete
# -----------------------

# %%
city_data_df=pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Atuona  -9.8000 -139.0333     25.78        72          15
# 1     Savonlinna  61.8699   28.8800    -21.97        84          90
# 2       Flinders -34.5833  150.8552     21.78        85          59
# 3   Punta Arenas -53.1500  -70.9167     17.06        36          75
# 4           Chuy -33.6971  -53.4616     25.85        57          80
# 5     Turukhansk  65.8167   87.9833    -19.43        97         100
# 6     Nikolskoye  59.7035   30.7861    -11.78        96         100
# 7          Kapaa  22.0752 -159.3190     24.18        68          40
# 8        Rikitea -23.1203 -134.9692     25.40        76         100
# 9  Usta Muhammad  28.1794   68.0445     19.02        23          88
#
#    Wind Speed       Description Country                 Date
# 0        7.78        few clouds      PF  2021-12-25 20:24:21
# 1        1.03   overcast clouds      FI  2021-12-25 20:24:22
# 2        4.36     broken clouds      AU  2021-12-25 20:24:22
# 3       13.38     broken clouds      CL  2021-12-25 20:24:14
# 4        3.31     broken clouds      UY  2021-12-25 20:24:23
# 5        4.26   overcast clouds      RU  2021-12-25 20:24:23
# 6        2.13        light snow      RU  2021-12-25 20:24:24
# 7        1.34  scattered clouds      US  2021-12-25 20:24:24
# 8        9.31        light rain      PF  2021-12-25 20:24:25
# 9        3.26   overcast clouds      PK  2021-12-25 20:24:25

# %%
city_data_df=city_data_df.rename(columns={"Description": "Current Description"})

# %%
city_data_df
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0              Atuona  -9.8000 -139.0333     25.78        72          15
# 1          Savonlinna  61.8699   28.8800    -21.97        84          90
# 2            Flinders -34.5833  150.8552     21.78        85          59
# 3        Punta Arenas -53.1500  -70.9167     17.06        36          75
# 4                Chuy -33.6971  -53.4616     25.85        57          80
# ..                ...      ...       ...       ...       ...         ...
# 680            Suntar  62.1444  117.6319    -32.84        99          96
# 681              Dori  14.0354   -0.0345     24.41        12         100
# 682  Villa Carlos Paz -31.4241  -64.4978     33.92        17          90
# 683      Bull Savanna  17.8868  -77.5902     25.84        68          82
# 684            Awbari  26.5921   12.7805     12.89        36           0
#
#      Wind Speed      Description Country                 Date
# 0          7.78       few clouds      PF  2021-12-25 20:24:21
# 1          1.03  overcast clouds      FI  2021-12-25 20:24:22
# 2          4.36    broken clouds      AU  2021-12-25 20:24:22
# 3         13.38    broken clouds      CL  2021-12-25 20:24:14
# 4          3.31    broken clouds      UY  2021-12-25 20:24:23
# ..          ...              ...     ...                  ...
# 680        1.63  overcast clouds      RU  2021-12-25 20:46:38
# 681        4.56  overcast clouds      BF  2021-12-25 20:46:40
# 682        2.68  overcast clouds      AR  2021-12-25 20:46:42
# 683        0.71    broken clouds      JM  2021-12-25 20:46:43
# 684        3.68        clear sky      LY  2021-12-25 20:46:43
#
# [685 rows x 10 columns]

# %%
city_data_df=city_data_df[["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]]

# %%
city_data_df
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0              Atuona      PF  -9.8000 -139.0333     25.78        72
# 1          Savonlinna      FI  61.8699   28.8800    -21.97        84
# 2            Flinders      AU -34.5833  150.8552     21.78        85
# 3        Punta Arenas      CL -53.1500  -70.9167     17.06        36
# 4                Chuy      UY -33.6971  -53.4616     25.85        57
# ..                ...     ...      ...       ...       ...       ...
# 680            Suntar      RU  62.1444  117.6319    -32.84        99
# 681              Dori      BF  14.0354   -0.0345     24.41        12
# 682  Villa Carlos Paz      AR -31.4241  -64.4978     33.92        17
# 683      Bull Savanna      JM  17.8868  -77.5902     25.84        68
# 684            Awbari      LY  26.5921   12.7805     12.89        36
#
#      Cloudiness  Wind Speed Current Description
# 0            15        7.78          few clouds
# 1            90        1.03     overcast clouds
# 2            59        4.36       broken clouds
# 3            75       13.38       broken clouds
# 4            80        3.31       broken clouds
# ..          ...         ...                 ...
# 680          96        1.63     overcast clouds
# 681         100        4.56     overcast clouds
# 682          90        2.68     overcast clouds
# 683          82        0.71       broken clouds
# 684           0        3.68           clear sky
#
# [685 rows x 9 columns]

# %%
city_data_df.to_csv(index=False,"Weather_database\WeatherPy_")
